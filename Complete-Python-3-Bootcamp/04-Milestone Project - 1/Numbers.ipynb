# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
23 % 2
# Out:
# 1

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a = a + a

# %%
a
# Out:
# 320

# %%
type(a)
# Out:
# int

# %%
a= 1.1

# %%
type(a)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1 

my_taxes = my_income*tax_rate

# %%
my_taxes
# Out:
# 10.0

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
"This is also a string"
# Out:
# 'This is also a string'

# %%
print("Hello")
# Out:
# Hello

# %%
mystring = "Hello World"

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-1]
# Out:
# 'd'

# %%
mystring = "abcasfasbsd"

# %%
mystring[2:]
# Out:
# 'casfasbsd'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'asf'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[3:9]
# Out:
# 'asfasb'

# %%
mystring[::]
# Out:
# 'abcasfasbsd'

# %%
mystring[::2]
# Out:
# 'acsabd'

# %%
mystring[::3]
# Out:
# 'aaas'

# %%
mystring[2:7:2] #[Start : Stop : Steps]
# Out:
# 'csa'

# %%
class Cookie:
