# %%
my_list = [1,2,3]

# %%
my_list=["STRING", 100, 3214.12432]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[0]
# Out:
# 'STRING'

# %%
my_list[1:]
# Out:
# [100, 3214.12432]

# %%
another_list = [4, 5]

# %%
new_list = my_list + another_list

# %%
new_list
# Out:
# ['STRING', 100, 3214.12432, 4, 5]

# %%
new_list[0] = "ONE ALL CAPS"

# %%
new_list
# Out:
# ['ONE ALL CAPS', 100, 3214.12432, 4, 5]

# %%
new_list.append("Six")

# %%
new_list
# Out:
# ['ONE ALL CAPS', 100, 3214.12432, 4, 5, 'Six']

# %%
new_list.pop()
# Out:
# 'Six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 100, 3214.12432, 4, 5]

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 5

# %%
new_list
# Out:
# ['ONE ALL CAPS', 100, 3214.12432, 4]

# %%
new_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list
# Out:
# [100, 3214.12432, 4]

# %%
new_list.pop(-1)
# Out:
# 4

# %%
new_list=['k', 'e', 'd', 'a']

# %% [markdown]
# num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'd', 'e', 'k']
