# %%
mylist = [1,2,3]

# %%
mylist.append(4)

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
def say_hello():
    print("Hello")
    print("Hello")
        print("Hello")

# %%
say_hello()
# Out:
# Hello

# %%
def say_hello(name = "Default"):
    print(f"Hello {name}")

# %%
say_hello()
# Out:
# Hello Default

# %%
def add_num(num1, num2):
    return num1 + num2

# %%
add_num(213124, 21421)
# Out:
# 234545

# %%
def print_result(a, b):
    print(a+b)

# %%
def return_result(a, b):
    return a+b

# %%
print_result(10,20)
# Out:
# 30

# %%
result = return_result(21213124,1241412)

# %%
result
# Out:
# 22454536
