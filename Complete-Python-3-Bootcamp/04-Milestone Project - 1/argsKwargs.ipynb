# %%
def myfunc(a,b,c=0,d=0,e=0):
    #Returns 5% of the sum of a and b
    return sum((a,b,c,d,e)) *0.05

# %%
myfunc(40,60,100,100,100,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 myfunc(40,60,100,100,100,3,4)
#
# TypeError: myfunc() takes from 2 to 5 positional arguments but 7 were given

# %%
def myfunc(*args):
    return sum(args) * 0.05

# %%
myfunc(40,60,100,1,3,4,1,)
# Out:
# 10.450000000000001

# %%
def myfunc(*args):
    for item in args:
        print(item)
    return sum(args) * 0.05

# %%
myfunc(100,100,1001,1,100)
# Out:
# 100
# 100
# 1001
# 1
# 100
# 65.10000000000001

# %%
def myfunc(**kwargs):
    print(kwargs)
    if 'fruit' in kwargs:
        print('My fruit of choice is {}'.format(kwargs['fruit']))
    else:
        print("I did not find any fruit here")

# %%
myfunc(fruit='Apple', veggie = 'lettuce')
# Out:
# {'fruit': 'Apple', 'veggie': 'lettuce'}
# My fruit of choice is Apple

# %%
def myfunc(*args, **kwargs):
    print(args)
    print(kwargs)
    print('I would like {} {}'.format(args[0],kwargs['food']))

# %%
myfunc(10,20,30, fruit = 'orange', food = 'eggs', animal ='dog')
# Out:
# (10, 20, 30)
# {'fruit': 'orange', 'food': 'eggs', 'animal': 'dog'}
# I would like 10 eggs

# %%
def myfunc(args):
    out=[]
    for x in range(len(args)):
        if isinstance(args[x], str): # Ensure the argument is a string
            if x % 2 == 0:
                out.append(args[x].upper()) # Append to list
            else:
                out.append(args[x].lower()) # Append to list
        else:
            out.append(str(arg[x])) # Convert non-string values to string
    
    return ''.join(out)
    
myfunc("Abrakadabra")
# Out:
# 'AbRaKaDaBrA'
