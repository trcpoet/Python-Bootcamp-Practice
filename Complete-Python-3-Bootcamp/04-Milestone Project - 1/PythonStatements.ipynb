# %%
hungry = True

if hungry:
    print("Feed me!")
else:
    print("I' not hungry")
# Out:
# Feed me!

# %%
loc = 'Store'

if loc == 'Auto shop':
    print("Cars are cool")
elif loc == "bank":
    print("Money is cool")
elif loc == "Store":
    print("Welcome to the store")
else:
    print("I don't know much")
# Out:
# Welcome to the store

# %%
name = "Sammy"

if name == "Frankie":
    print("Hello Frankie")
elif name =="Sammy":
    print("Hello Sammy")
else:
    print("What is your name?")
# Out:
# Hello Sammy
