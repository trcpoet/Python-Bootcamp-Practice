# %%
def add(n1,n2):
    print(n1+n2)

# %%
add(10,20)
# Out:
# 30

# %%
number1 = 10

# %%
# number2 = int(input("Please provide a number: "))
number2 = input("Please provide a number: ")
# Out:
# Please provide a number:  20

# %%
add(number1,number2)
print("Something happened")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 add(number1,number2)
#       2 print("Something happened")
#
# Cell In[1], line 2, in add(n1, n2)
#       1 def add(n1,n2):
# ----> 2     print(n1+n2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    # WANT TO ATTEMPT THIS CODE 
    # MAY HAVE AN ERROR 
    result = 10 + 10
except:
    print("Hey it looks like you aren't adding correctly!")
else:
    print("Add went well!")
    print(result)
# Out:
# Add went well!
# 20

# %%
result
# Out:
# 20

# %%
try:
    f = open('testfile', 'r')
    f.write("Write a test line")
except TypeError:
    print("There was a type error!")
except:
    print("All other exceptions!") #When you're opening and writing to files you don't have permission to
    print("Hey you have an OS error")
finally:
    print("I always run")
# Out:
# All other exceptions!
# Hey you have an OS error
# I always run

# %%
def ask_for_int():
    
    while True:
        try:
            result = int(input("Please provide a number: "))
        except:
            print("Whoops! That is not a number")
            continue
        else:
            print("Yes, thank you")
            break

# %%
ask_for_int()
# Out:
# Please provide a number:  q
# Whoops! That is not a number
# Please provide a number:  20
# Yes, thank you
