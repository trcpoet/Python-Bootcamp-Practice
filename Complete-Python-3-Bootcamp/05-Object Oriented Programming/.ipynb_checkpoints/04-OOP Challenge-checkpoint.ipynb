# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Object Oriented Programming Challenge
#
# For this challenge, create a bank account class that has two attributes:
#
# * owner
# * balance
#
# and two methods:
#
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
#
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account can't be overdrawn.

# %%
class Account():
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance
        print(f"Account owner: {self.owner}")
        print(f"Account balance: {self.balance}")


    def deposit(self, deposit_cash):
        self.balance = self.balance+ deposit_cash
        print(f"Added {deposit_cash} to the balance")
              
        # deposit_cash = float(input("How much would you like to deposit? "))
        # if deposit_cash == 0 and deposit_cash <= 0:
        #     print("Invalid")
        # else:
        #     deposit_cash = float(self.balance + deposit_cash)
        #     return deposit_cash
        #     print("Deposit Accepted!")

    def withdraw(self, withdraw_cash):
        if self.balance >= withdraw_cash:
            self.balance = self.balance - withdraw_cash
            print("Withdraw accepted")
        else:
            print("Sorry not enough funds!")


    def __str__(self):
        return f"Owner: {self.owner} \nBalance: {self.balance}"
            
        
        # withdraw_cash = float(input("How much would you like to withdraw? "))
        # if withdraw_cash == 0 and withdraw_cash <= 0:
        #     print("Invalid")
        # elif withdraw_cash >= self.balance:
        #     print("Funds Unavailable")
        # else:
        #     withdraw_cash = float(self.balance - withdraw_cash)
        #     return withdraw_cash
        #     print("Withdraw Accepted!")

# %%
# 1. Instantiate the class
acct1 = Account('Jose',100)
# Out:
# Account owner: Jose
# Account balance: 100

# %%
# 2. Print the object
print(acct1)
# Out:
# Owner: Jose
# Balance: 100

# %%
# 3. Show the account owner attribute
acct1.owner
# Out:
# 'Jose'

# %%
# 4. Show the account balance attribute
acct1.balance
# Out:
# 100

# %%
# 5. Make a series of deposits and withdrawals
acct1.deposit(50)
# Out:
# Added 50 to the balance

# %%
acct1.withdraw(75)
# Out:
# Withdraw accepted

# %%
# 6. Make a withdrawal that exceeds the available balance
acct1.withdraw(500)
# Out:
# Sorry not enough funds!

# %% [markdown]
# ## Good job!
