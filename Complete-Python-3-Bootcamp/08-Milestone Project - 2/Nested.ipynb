# %%
x = 25

def printer():
    x = 50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %%
#lambda num:num**2

# %%
name = 'This is a locala string'

# %%
name= 'Global'
def greet():
    # name = 'Enclosing'
    def hello():
        # name = 'Local'
        print('Hello '+ name)
    hello()

greet()
# Out:
# Hello Global

# %%
x = 50

def func(x):
    print(f'X is {x}')
    
    #Local reassignment on a global variable 
    x = 'NEW VALUE'
    print(f"I just locally changed global x to {x}")
    return x

# %%
print(x)
# Out:
# 50

# %%
x = func(x)
# Out:
# X is 50
# I just locally changed global x to NEW VALUE

# %%
print(x)
# Out:
# NEW VALUE
