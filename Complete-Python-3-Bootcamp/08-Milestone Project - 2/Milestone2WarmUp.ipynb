# %%
import random

# %%
suits = ("Hearts", "Diamonds", "Spades", "Clubs")
ranks = ("Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "King", "Queen", "Ace")
values = {"Two": 2, "Three":3, "Four":4, "Five":5, "Six":6, "Seven":7, "Eight":8, 
          "Nine":9, "Ten":10, "Jack":11, "King":12, "Queen":13, "Ace":14}

# %%
class Card:
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]

    def __str__(self):
        return self.rank + " of " + self.suit

# %%
three_of_clubs = Card("Clubs", "Three")

# %% [raw]
# three_of_clubs.suit

# %%
three_of_clubs.rank
# Out:
# 'Three'

# %% [raw]
# three_of_clubs.suit

# %%
three_of_clubs.suit
# Out:
# 'Clubs'

# %%
three_of_clubs.value
# Out:
# 3

# %%
two_hearts = Card("Hearts", "Two")

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
two_hearts.suit
# Out:
# 'Hearts'

# %%
two_hearts.rank
# Out:
# 'Two'

# %%
values[two_hearts.rank]
# Out:
# 2

# %%
two_hearts.value < three_of_clubs.value
# Out:
# True

# %%
#DECK CLASS
##We will see that the Deck class holds a list of Card Objects 
##This means the Deck class will return Card class object instances, 
##not just normal python data types
##We have a class object using instances of another class as part of its attribute 
#Instead of integers or strings, we are holding our specific card object

# %%
#1 Instantiate a new deck
##Create all 52 Card objects 
##Hold as a list of Card objects 

#2 Shuffle a Deck through a method call
##Random library shuffle() function

#3 Deal cards from the Deck object
##Pop a method from cards list

# %%
class Deck:

    def __init__(self):
        
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                # Create the Card Object
                created_card = Card(suit, rank)
                
                self.all_cards.append(created_card)

    def shuffle(self):

        random.shuffle(self.all_cards)

    def deal_one(self): #Method that can grab a card from the list
        return self.all_cards.pop() #Returns a single card

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %% [raw]
# mycard = new_deck.deal_one()

# %% [raw]
# mycard

# %% [raw]
# print(mycard)

# %%
mycard = new_deck.deal_one()
mycard
print(mycard)
# Out:
# Five of Clubs

# %%
len(new_deck.all_cards)
# Out:
# 51

# %%
first_card = new_deck.all_cards[0]

# %%
print(first_card)
# Out:
# Four of Clubs

# %%
last_card = new_deck.all_cards[-1]

# %%
print(last_card)
# Out:
# Eight of Clubs

# %%
for card_object in new_deck.all_cards:
    print(card_object)
# Out:
# Four of Clubs
# Three of Diamonds
# Two of Spades
# Ace of Hearts
# Two of Clubs
# Seven of Diamonds
# Eight of Diamonds
# Three of Clubs
# Ace of Clubs
# King of Clubs
# Six of Hearts
# Six of Spades
# Jack of Clubs
# King of Hearts
# Five of Diamonds
# Nine of Spades
# Jack of Diamonds
# Ten of Diamonds
# Five of Spades
# Ten of Hearts
# Nine of Clubs
# Four of Spades
# Four of Hearts
# Five of Hearts
# Ten of Clubs
# Ace of Diamonds
# Ace of Spades
# King of Diamonds
# Ten of Spades
# Two of Hearts
# Jack of Spades
# Six of Diamonds
# Queen of Spades
# Seven of Clubs
# Seven of Hearts
# Eight of Hearts
# Queen of Hearts
# Seven of Spades
# Six of Clubs
# Three of Hearts
# Jack of Hearts
# Queen of Clubs
# Eight of Spades
# King of Spades
# Nine of Diamonds
# Nine of Hearts
# Two of Diamonds
# Queen of Diamonds
# Four of Diamonds
# Three of Spades
# Eight of Clubs

# %%
bottom_card = new_deck.all_cards[-1]

# %%
print(bottom_card)
# Out:
# Eight of Clubs

# %%
new_deck.shuffle()

# %%
print(new_deck.all_cards[-1])
# Out:
# Nine of Hearts

# %%
print(bottom_card)
# Out:
# Eight of Clubs

# %%
print(new_deck.all_cards[0])
# Out:
# Jack of Diamonds

# %%
#Player Class

# %%
#We will want the player to be able to add a single card or multiple cards to their list, so we will 
#also explore how to do this in one method call

#The last thing we need to think about is translating a Deck/Hand of cards with a top and bottom, to a
#Python list. Lets try to visualize this.

# %%
#Player class will have a self.all_cards list

# %%
class Player:

    def __init__(self, name):

        self.name = name 
        self.all_cards = [] #all_cards is 


    def remove_one(self):
        return self.all_cards.pop(0)

    def add_cards(self, new_cards):
        if type(new_cards) == type([]): #if type of new cards == type of empty list, which is a list
            # List of multiple Card objects 
            self.all_cards.extend(new_cards) #Can't append a list because it creates nested lists
        else:
            #For a single card object 
            self.all_cards.append(new_cards)

    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
new_player = Player("Jose")

# %%
print(new_player)
# Out:
# Player Jose has 0 cards

# %%
new_player.add_cards(mycard)

# %%
print(new_player.all_cards[0])
# Out:
# Five of Clubs

# %%
new_player.add_cards([mycard,mycard,mycard])

# %%
print(new_player)
# Out:
# Player Jose has 4 cards

# %%
new_player.remove_one()

# %%
#PLAYER class is working: We can add single cards, we can add multiple cards,
#And we can clearly remove a single card

# %%
#GAME LOGIC is often the hardest part to write in any project
#Upcoming classes planned around this logic
#So in the real world, you think about the logic and class simultaneously

# %%
#OUTLINE FOR THE GAME LOGIC

# %%
#CREATE INSTANCES OF PLAYER 1 AND 2, AND AN INSTANCE OF A NEW DECK THAT IS SHUFFLED AND SPLIT BETWEEN THEM

# %%
#WHILE GAME_ON
#COMPARE CARDS 
#WAR IF CARDS ARE == TO EACH OTHER SO DRAW ADITIONAL 3 CARDS 
#WHILE AT_WAR LOOP CAUSE SOMETIMES YOU CAN HAVE TWO WARS IN A ROW
#WHICH MEANS HAVE TWO CARDS EQUAL TO EACH OTHER, DRAW THE EXTRA CARDS,
#AND NEW CARDS FOR THE NEW MATCHUPS MAY ALSO GET YOU ANOTHER TIE

# %%
#Game Setup
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
    #Adds two cards for each iteration of this for loop

# %%
# #Game Setup
# player_one = Player("One")
# player_two = Player("Two")

# new_deck = Deck()
# new_deck.shuffle()

# for x in range(26):
#     player_one.add_cards(new_deck.deal_one())
#     player_two.add_cards(new_deck.deal_one())
#     #Adds two cards for each iteration of this for loop

# %%
#While game_on
    #while at_war

# %%
print(player_one.all_cards[0])
# Out:
# Three of Clubs

# %%
game_on = True

# %%
game_on = True
round_num = 0

while game_on:
    round_num += 1
    print(f"Round{round_num}")

    if len(player_one.all_cards) == 0:
        print("Player One, out of cards! Player Two wins!")
        game_on = False
        break
    if len(player_two.all_cards) == 0:
        print("Player Two, out of cards! Player One wins!")
        game_on = False
        break

    #START A NEW ROUND
    player_one_cards = [] #Cards the player's gonna leave on the table; Current cards in play
    player_one_cards.append(player_one.remove_one()) #Not like player_one.all_cards, which is all the cards they have in hand 
    
    player_two_cards = [] #Remove a card from their list of all_cards and append it to cards in play
    player_two_cards.append(player_two.remove_one()) 


    at_war = True

    while at_war:

        if player_one_cards[-1].value > player_two_cards[-1].value:

            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)

            at_war = False

        elif player_one_cards[-1].value < player_two_cards[-1].value:

            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)

            at_war = False

        else:
            print("WAR")

            if len(player_one.all_cards) < 5:
                print("Player One unable to declare war")
                print("PLAYER TWO WINS!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player two unable to declare war")
                print("PLAYER ONE WINS!")
                game_on = False
                break

            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round1
# Round2
# Round3
# Round4
# Round5
# Round6
# Round7
# Round8
# Round9
# Round10
# Round11
# WAR
# Player One unable to declare war
# PLAYER TWO WINS!
